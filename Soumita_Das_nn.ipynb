# %% [markdown]
# ### Problem statement:
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.

# %% [markdown]
# ### Import all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import PIL
import keras.layers.experimental.preprocessing
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.preprocessing.image import load_img
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
#from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
#from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Data Reading/Data Understanding

# %%
#unzip the dataset
# !unzip "/content/gdrive/MyDrive/CNN_Data_SkincancerISIC.zip" > /dev/null

# %%
# Define the path for both train and test images from dataset
#data_dir_train = pathlib.Path("/content/Skin cancer ISIC data/Train/")
#data_dir_test = pathlib.Path("/content/Skin cancer ISIC data/Test/")
data_dir_train = pathlib.Path("./CNN_Data_SkincancerISIC/Train")
data_dir_test = pathlib.Path('./CNN_Data_SkincancerISIC/Test')

# %%
# Count the number of image in Train and Test folder
# Using the glob to retrieve files/pathnames matching a specified pattern.

#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Dataset creation
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Train dataset
## Note use seed=123 while creating your dataset
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Validation dataset
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# We can find the class names in the class_names attribute on these datasets.

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Dataset Visualization
#
# Create a code to visualize one instance of all the nine classes present in the dataset

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))

#Visualize image
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 2239 files belonging to 9 classes.

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
#overlaps data preprocessing and model execution while training., Speed up training
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Class Distribution
# ##### Visualize distribution of classes in the training dataset

# %%
def class_distribution_count(directory):

    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))

    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0     squamous cell carcinoma           181
# 1        seborrheic keratosis            77
# 2        basal cell carcinoma           376
# 3                       nevus           357
# 4           actinic keratosis           114
# 5             vascular lesion           139
# 6  pigmented benign keratosis           462
# 7              dermatofibroma            95
# 8                    melanoma           438

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")
# Out:
# <Axes: xlabel='No. of Image', ylabel='Class'>

# %% [markdown]
# ### Create model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset.
# Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1).
# The RGB channel values are in the `[0, 255]` range.
# This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
num_classes = 9

#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  #2D convolution layer (e.g. spatial convolution over images).
  layers.Conv2D(16, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
  layers.MaxPooling2D(),

  #We slide over the feature map and extract tiles of a specified size.
  layers.Conv2D(32, 3, padding='same', activation='relu'),

  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.MaxPooling2D(),

  #Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  ##Flattens the input. Does not affect the batch size.
  layers.Flatten(),

  #fully connected layer
  #A hidden layer in which each node is connected to every node in the subsequent hidden layer.
  #A fully connected layer is also known as a dense layer.

  layers.Dense(128, activation='relu'),

  #Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
  #It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
  #Dense implements the operation: output = activation(dot(input, kernel)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
## compile the model
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 21s 104ms/step - loss: 1.9535 - accuracy: 0.2757 - val_loss: 1.7314 - val_accuracy: 0.4004
# Epoch 2/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.6228 - accuracy: 0.4196 - val_loss: 1.6833 - val_accuracy: 0.4295
# Epoch 3/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.4551 - accuracy: 0.4900 - val_loss: 1.5790 - val_accuracy: 0.4631
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3310 - accuracy: 0.5441 - val_loss: 1.3935 - val_accuracy: 0.5414
# Epoch 5/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.2175 - accuracy: 0.5664 - val_loss: 1.3824 - val_accuracy: 0.5101
# Epoch 6/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.1640 - accuracy: 0.5792 - val_loss: 1.4760 - val_accuracy: 0.5235
# Epoch 7/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.0344 - accuracy: 0.6367 - val_loss: 1.4144 - val_accuracy: 0.5727
# Epoch 8/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9616 - accuracy: 0.6546 - val_loss: 1.3461 - val_accuracy: 0.5749
# Epoch 9/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.8568 - accuracy: 0.6920 - val_loss: 1.4078 - val_accuracy: 0.5727
# Epoch 10/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7943 - accuracy: 0.7160 - val_loss: 1.4974 - val_accuracy: 0.5570
# Epoch 11/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.7232 - accuracy: 0.7427 - val_loss: 1.7693 - val_accuracy: 0.5302
# Epoch 12/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.6659 - accuracy: 0.7589 - val_loss: 1.7764 - val_accuracy: 0.5503
# Epoch 13/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6620 - accuracy: 0.7667 - val_loss: 1.6857 - val_accuracy: 0.5190
# Epoch 14/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6141 - accuracy: 0.7807 - val_loss: 1.7626 - val_accuracy: 0.5526
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5614 - accuracy: 0.8013 - val_loss: 2.2500 - val_accuracy: 0.4474
# Epoch 16/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5330 - accuracy: 0.8052 - val_loss: 1.9324 - val_accuracy: 0.5503
# Epoch 17/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4215 - accuracy: 0.8398 - val_loss: 2.0107 - val_accuracy: 0.5481
# Epoch 18/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3385 - accuracy: 0.8672 - val_loss: 2.0284 - val_accuracy: 0.5503
# Epoch 19/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.3223 - accuracy: 0.8767 - val_loss: 2.0496 - val_accuracy: 0.5391
# Epoch 20/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2675 - accuracy: 0.8906 - val_loss: 2.4244 - val_accuracy: 0.5436

# %% [markdown]
# ### Train the model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Data augmentation

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
    layers.experimental.preprocessing.RandomTranslation(1,.5,fill_mode="reflect",interpolation="bilinear",seed=None,fill_value=0.0),
    layers.experimental.preprocessing.RandomCrop(img_height,img_width),
  ]
)

# %%
for images, _ in train_ds.take(1):
    print("Number of images:", len(images))
    print("Image shape:", images[0].shape)
    print("Image data type:", images[0].dtype)
# Out:
# Number of images: 32
# Image shape: (180, 180, 3)
# Image data type: <dtype: 'float32'>

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 16s 140ms/step - loss: 2.0807 - accuracy: 0.2165 - val_loss: 1.9402 - val_accuracy: 0.2103
# Epoch 2/20
# 56/56 [==============================] - 7s 121ms/step - loss: 1.9165 - accuracy: 0.2790 - val_loss: 1.7556 - val_accuracy: 0.3579
# Epoch 3/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.8883 - accuracy: 0.3013 - val_loss: 1.6533 - val_accuracy: 0.3848
# Epoch 4/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.7080 - accuracy: 0.3583 - val_loss: 1.6382 - val_accuracy: 0.3691
# Epoch 5/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.7044 - accuracy: 0.3477 - val_loss: 1.6279 - val_accuracy: 0.4161
# Epoch 6/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.6285 - accuracy: 0.3917 - val_loss: 1.6756 - val_accuracy: 0.3982
# Epoch 7/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.5722 - accuracy: 0.4113 - val_loss: 1.7128 - val_accuracy: 0.3289
# Epoch 8/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.5789 - accuracy: 0.4001 - val_loss: 1.5621 - val_accuracy: 0.4474
# Epoch 9/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.5857 - accuracy: 0.4018 - val_loss: 1.5591 - val_accuracy: 0.4295
# Epoch 10/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.5357 - accuracy: 0.4280 - val_loss: 1.6841 - val_accuracy: 0.4251
# Epoch 11/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.5679 - accuracy: 0.4258 - val_loss: 1.5399 - val_accuracy: 0.4787
# Epoch 12/20
# 56/56 [==============================] - 7s 120ms/step - loss: 1.4850 - accuracy: 0.4660 - val_loss: 1.5770 - val_accuracy: 0.4139
# Epoch 13/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.5428 - accuracy: 0.4247 - val_loss: 1.5733 - val_accuracy: 0.4139
# Epoch 14/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.5242 - accuracy: 0.4364 - val_loss: 1.4717 - val_accuracy: 0.4698
# Epoch 15/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.4498 - accuracy: 0.4704 - val_loss: 1.5334 - val_accuracy: 0.4832
# Epoch 16/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.4747 - accuracy: 0.4637 - val_loss: 1.5951 - val_accuracy: 0.4340
# Epoch 17/20
# 56/56 [==============================] - 7s 119ms/step - loss: 1.4708 - accuracy: 0.4732 - val_loss: 1.4704 - val_accuracy: 0.4676
# Epoch 18/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.4043 - accuracy: 0.4967 - val_loss: 1.4758 - val_accuracy: 0.4765
# Epoch 19/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.4342 - accuracy: 0.4754 - val_loss: 1.6231 - val_accuracy: 0.4139
# Epoch 20/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.4309 - accuracy: 0.4827 - val_loss: 1.5209 - val_accuracy: 0.4519

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# For convenience, let us set up the path for the training and validation sets
train_dir = os.path.join('./CNN_Data_SkincancerISIC/Train')
val_dir = os.path.join('./CNN_Data_SkincancerISIC/Test')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Setting batch size and image size
batch_size = 100
IMG_SHAPE = 224

# Create training images generator
#Generate batches of tensor image data with real-time data augmentation.
#https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
#https://keras.io/api/preprocessing/image/
#Then calling image_dataset_from_directory(main_directory, labels='inferred') will return a tf.data.Dataset that yields batches of images from the subdirectories
train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )

# Create validation images generator
image_gen_val = ImageDataGenerator(rescale=1./255)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 2239 images belonging to 9 classes.
# Found 118 images belonging to 9 classes.

# %%
#Create a CNN model
#Experiment #1
#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# Import layers explicitly to keep our code compact
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D


model = Sequential()

#2D convolution layer (e.g. spatial convolution over images).
model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
#Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))

#Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

#Flattens the input. Does not affect the batch size.
model.add(Flatten())

#https://keras.io/api/layers/regularization_layers/dropout/
#The Dropout layer randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over all inputs is unchanged
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))

#Just your regular densely-connected NN layer.
#Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
#It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
#Dense implements the operation: output = activation(dot(input, kernel)
model.add(Dense(9))

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
epochs = 20

history = model.fit(
  train_data_gen,
  validation_data=val_data_gen,
  epochs=10
)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 60s 2s/step - loss: 2.5212 - accuracy: 0.1648 - val_loss: 2.2562 - val_accuracy: 0.1780
# Epoch 2/10
# 23/23 [==============================] - 58s 3s/step - loss: 1.9633 - accuracy: 0.2546 - val_loss: 2.7030 - val_accuracy: 0.1441
# Epoch 3/10
# 23/23 [==============================] - 51s 2s/step - loss: 1.8452 - accuracy: 0.3162 - val_loss: 2.0917 - val_accuracy: 0.2373
# Epoch 4/10
# 23/23 [==============================] - 52s 2s/step - loss: 1.6508 - accuracy: 0.4140 - val_loss: 2.2878 - val_accuracy: 0.2373
# Epoch 5/10
# 23/23 [==============================] - 52s 2s/step - loss: 1.6017 - accuracy: 0.4346 - val_loss: 2.1179 - val_accuracy: 0.2542
# Epoch 6/10
# 23/23 [==============================] - 54s 2s/step - loss: 1.5200 - accuracy: 0.4707 - val_loss: 2.2071 - val_accuracy: 0.3136
# Epoch 7/10
# 23/23 [==============================] - 50s 2s/step - loss: 1.4359 - accuracy: 0.4980 - val_loss: 2.3952 - val_accuracy: 0.3305
# Epoch 8/10
# 23/23 [==============================] - 53s 2s/step - loss: 1.3818 - accuracy: 0.5203 - val_loss: 2.2354 - val_accuracy: 0.3305
# Epoch 9/10
# 23/23 [==============================] - 51s 2s/step - loss: 1.4422 - accuracy: 0.4752 - val_loss: 2.1371 - val_accuracy: 0.3898
# Epoch 10/10
# 23/23 [==============================] - 53s 2s/step - loss: 1.3490 - accuracy: 0.5284 - val_loss: 2.1210 - val_accuracy: 0.3898

# %%
import matplotlib.pyplot as plt
epochs=10
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)



plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
len(path_list)
# Out:
# 2239

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path  \
# 0     CNN_Data_SkincancerISIC/Train/squamous cell ca...
# 1     CNN_Data_SkincancerISIC/Train/squamous cell ca...
# 2     CNN_Data_SkincancerISIC/Train/squamous cell ca...
# 3     CNN_Data_SkincancerISIC/Train/squamous cell ca...
# 4     CNN_Data_SkincancerISIC/Train/squamous cell ca...
# ...                                                 ...
# 2234  CNN_Data_SkincancerISIC/Train/melanoma/ISIC_00...
# 2235  CNN_Data_SkincancerISIC/Train/melanoma/ISIC_00...
# 2236  CNN_Data_SkincancerISIC/Train/melanoma/ISIC_00...
# 2237  CNN_Data_SkincancerISIC/Train/melanoma/ISIC_00...
# 2238  CNN_Data_SkincancerISIC/Train/melanoma/ISIC_00...
#
#                         Label
# 0     squamous cell carcinoma
# 1     squamous cell carcinoma
# 2     squamous cell carcinoma
# 3     squamous cell carcinoma
# 4     squamous cell carcinoma
# ...                       ...
# 2234                 melanoma
# 2235                 melanoma
# 2236                 melanoma
# 2237                 melanoma
# 2238                 melanoma
#
# [2239 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=7, n=181 (8.084%)
# Class=6, n=77 (3.439%)
# Class=1, n=376 (16.793%)
# Class=4, n=357 (15.945%)
# Class=0, n=114 (5.092%)
# Class=8, n=139 (6.208%)
# Class=5, n=462 (20.634%)
# Class=2, n=95 (4.243%)
# Class=3, n=438 (19.562%)

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
datapath = r'./CNN_Data_SkincancerISIC/Train/actinic keratosis'
import Augmentor
p = Augmentor.Pipeline(datapath)
#Every function requires you to specify a probability, which is used to decide if an operation is applied to an image as it is passed through the augmentation pipeline.
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.zoom(probability=0.2, min_factor=1.1, max_factor=1.2)
p.sample(300)
p.process()
# Out:
# Initialised with 114 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C452BAD40>: 100%|██████████| 300/300 [00:14<00:00, 20.84 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C454074C0>: 100%|██████████| 114/114 [00:04<00:00, 22.94 Samples/s]

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="./CNN_Data_SkincancerISIC/Train//"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C45307EE0>: 100%|██████████| 500/500 [00:15<00:00, 33.02 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C46BBF8B0>: 100%|██████████| 500/500 [00:15<00:00, 32.90 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C452CB7F0>: 100%|██████████| 500/500 [00:15<00:00, 31.72 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7E1C45406AA0>: 100%|██████████| 500/500 [01:24<00:00,  5.89 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C45D5EBC0>: 100%|██████████| 500/500 [01:15<00:00,  6.60 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7E1C46E9B6A0>: 100%|██████████| 500/500 [00:15<00:00, 32.41 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7E1C45407070>: 100%|██████████| 500/500 [00:35<00:00, 13.98 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7E1C45D5CFD0>: 100%|██████████| 500/500 [00:14<00:00, 33.51 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to ./CNN_Data_SkincancerISIC/Train//vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7E1CC80AC160>: 100%|██████████| 500/500 [00:15<00:00, 31.43 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4914

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new
# Out:
# ['CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030175.jpg_97ea56c3-8987-419b-a6d4-f9fe5b7c1568.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0029598.jpg_1159ba2d-82bc-4aec-b9d8-2a3ffb24d548.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0033869.jpg_e06bbb63-d963-4943-b0a6-135b96f8ecd2.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028381.jpg_6a897134-35bb-4b82-9a26-bb1e98eae6ea.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028795.jpg_e61d9c80-3a48-4d16-865b-229dea9fb1ba.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025358.jpg_ad36434e-ff6d-4d31-8a2f-1ed6b744af22.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025411.jpg_62e84ac2-a72f-4a75-b11e-48e49df6f5f4.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030076.jpg_28ca3fd4-9ad9-439e-9e04-91fc69dc804f.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030707.jpg_6a8d6c9f-70c0-4668-8172-d6e72d7861b6.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0031692.jpg_b6f7e1eb-4262-448b-9c6a-dbad65ae3808.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028372.jpg_344590e9-81c6-46c5-bd8a-9ff942599340.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0032154.jpg_37595ff0-b9db-4df5-8834-6597a4dfb6bb.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0028816.jpg_e8254e15-94ea-4633-88ca-a6a06c921dba.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0027719.jpg_c7f35d4f-5570-4d03-a684-7a1f7a984f4b.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0025831.jpg_af34d203-7988-4c98-b1c3-248aeb6dea13.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0026132.jpg_b597dc26-e1e8-4659-8e5e-423becd26089.jpg',
#  'CNN_Data_SkincancerISIC/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0
dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(df_dict_new.items()),columns = ['Path','Label'])

new_df = pd.concat([original_df, df2])

# %%
original_df.head(2)
# Out:
#                                                 Path                    Label
# 0  CNN_Data_SkincancerISIC/Train/squamous cell ca...  squamous cell carcinoma
# 1  CNN_Data_SkincancerISIC/Train/squamous cell ca...  squamous cell carcinoma

# %%
df2.head(2)
# Out:
#                                                 Path                    Label
# 0  CNN_Data_SkincancerISIC/Train/squamous cell ca...  squamous cell carcinoma
# 1  CNN_Data_SkincancerISIC/Train/squamous cell ca...  squamous cell carcinoma

# %%
new_df['Label'].value_counts()
# Out:
# Label
# actinic keratosis             1028
# pigmented benign keratosis     962
# melanoma                       938
# basal cell carcinoma           876
# nevus                          857
# squamous cell carcinoma        681
# vascular lesion                639
# dermatofibroma                 595
# seborrheic keratosis           577
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ### Model Building & training on the augmented data

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create Training dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training', ## Todo choose the correct parameter value, so that only training data is refered to
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7153 files belonging to 9 classes.
# Using 5723 files for training.

# %% [markdown]
# #### Create Validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7153 files belonging to 9 classes.
# Using 1430 files for validation.

# %% [markdown]
# #### Create model (make sure to include normalization)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile the model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Model Building & training on the rectified class imbalance data (Epoch 30)

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 179/179 [==============================] - 33s 61ms/step - loss: 1.8290 - accuracy: 0.3143 - val_loss: 1.4919 - val_accuracy: 0.4622
# Epoch 2/30
# 179/179 [==============================] - 5s 28ms/step - loss: 1.3767 - accuracy: 0.4896 - val_loss: 1.3020 - val_accuracy: 0.5063
# Epoch 3/30
# 179/179 [==============================] - 5s 27ms/step - loss: 1.1399 - accuracy: 0.5878 - val_loss: 1.1893 - val_accuracy: 0.5476
# Epoch 4/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.9413 - accuracy: 0.6677 - val_loss: 1.0693 - val_accuracy: 0.6434
# Epoch 5/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.7367 - accuracy: 0.7381 - val_loss: 0.9476 - val_accuracy: 0.6776
# Epoch 6/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.5725 - accuracy: 0.8031 - val_loss: 0.8345 - val_accuracy: 0.7294
# Epoch 7/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.4984 - accuracy: 0.8303 - val_loss: 0.8190 - val_accuracy: 0.7413
# Epoch 8/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.3690 - accuracy: 0.8758 - val_loss: 0.7520 - val_accuracy: 0.7881
# Epoch 9/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.3225 - accuracy: 0.8924 - val_loss: 0.8699 - val_accuracy: 0.7490
# Epoch 10/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.2633 - accuracy: 0.9086 - val_loss: 0.9400 - val_accuracy: 0.7336
# Epoch 11/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.2190 - accuracy: 0.9196 - val_loss: 0.8082 - val_accuracy: 0.7720
# Epoch 12/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.2018 - accuracy: 0.9273 - val_loss: 0.9052 - val_accuracy: 0.7825
# Epoch 13/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1733 - accuracy: 0.9376 - val_loss: 0.8037 - val_accuracy: 0.8070
# Epoch 14/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1785 - accuracy: 0.9362 - val_loss: 0.9257 - val_accuracy: 0.7762
# Epoch 15/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1876 - accuracy: 0.9355 - val_loss: 0.8056 - val_accuracy: 0.8098
# Epoch 16/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.1512 - accuracy: 0.9394 - val_loss: 0.9327 - val_accuracy: 0.7825
# Epoch 17/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1864 - accuracy: 0.9317 - val_loss: 0.9787 - val_accuracy: 0.7881
# Epoch 18/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1553 - accuracy: 0.9364 - val_loss: 0.9691 - val_accuracy: 0.8021
# Epoch 19/30
# 179/179 [==============================] - 5s 29ms/step - loss: 0.1297 - accuracy: 0.9512 - val_loss: 0.9821 - val_accuracy: 0.7895
# Epoch 20/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.1519 - accuracy: 0.9430 - val_loss: 1.1090 - val_accuracy: 0.7671
# Epoch 21/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.1423 - accuracy: 0.9418 - val_loss: 0.8935 - val_accuracy: 0.7930
# Epoch 22/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1331 - accuracy: 0.9490 - val_loss: 1.0727 - val_accuracy: 0.8021
# Epoch 23/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1078 - accuracy: 0.9567 - val_loss: 0.9804 - val_accuracy: 0.8028
# Epoch 24/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.1086 - accuracy: 0.9544 - val_loss: 0.9788 - val_accuracy: 0.7923
# Epoch 25/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.0961 - accuracy: 0.9591 - val_loss: 0.9672 - val_accuracy: 0.8105
# Epoch 26/30
# 179/179 [==============================] - 5s 29ms/step - loss: 0.0982 - accuracy: 0.9586 - val_loss: 0.9917 - val_accuracy: 0.8091
# Epoch 27/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1085 - accuracy: 0.9561 - val_loss: 1.0125 - val_accuracy: 0.8112
# Epoch 28/30
# 179/179 [==============================] - 5s 28ms/step - loss: 0.1421 - accuracy: 0.9465 - val_loss: 1.2705 - val_accuracy: 0.7797
# Epoch 29/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1587 - accuracy: 0.9374 - val_loss: 1.2111 - val_accuracy: 0.7350
# Epoch 30/30
# 179/179 [==============================] - 5s 27ms/step - loss: 0.1206 - accuracy: 0.9511 - val_loss: 1.0784 - val_accuracy: 0.7853

# %% [markdown]
# #### Visualize the results of the Model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The class rebalancing notably mitigated overfitting, resulting in a reduction in loss. However, it led to a significant decrease in accuracy.
#
# Initially, we experimented without utilizing the ImageDataGenerator, leading to severe overfitting issues.
#
# Subsequently, we incorporated dropout and ImageDataGenerator techniques, effectively mitigating overfitting.
#
# Finally, we implemented Batch Normalization and augmentation, resulting in further improvements and addressing the overfitting challenges.
